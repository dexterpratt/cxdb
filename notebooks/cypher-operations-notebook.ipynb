# %% [markdown]
# # Experimenting with CXDB and Cypher Queries
#
# This notebook contains example Cypher operations to explore and analyze your knowledge graph. Customize the property names and values to match your specific graph structure.

# %%
import sys
import os

# Add the parent directory of the current script to the Python path
cwd = os.getcwd()
dirname = os.path.dirname(cwd)
subdir = os.path.join(dirname, 'cxdb')
print(cwd)
print(dirname)
print(subdir)
sys.path.append(dirname)
sys.path.append(subdir)


print(sys.path)
# Out:
# /Users/idekeradmin/Dropbox/GitHub/cxdb/notebooks
# /Users/idekeradmin/Dropbox/GitHub/cxdb
# /Users/idekeradmin/Dropbox/GitHub/cxdb/cxdb
# ['/opt/anaconda3/envs/cxdb_env/lib/python312.zip', '/opt/anaconda3/envs/cxdb_env/lib/python3.12', '/opt/anaconda3/envs/cxdb_env/lib/python3.12/lib-dynload', '', '/opt/anaconda3/envs/cxdb_env/lib/python3.12/site-packages', '/Users/idekeradmin/Dropbox/GitHub/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb/notebooks/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb/notebooks/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb', '/Users/idekeradmin/Dropbox/GitHub/cxdb/cxdb']

# %%
from cxdb.core import CXDB
from cxdb.ndex import NDExConnector
from cxdb.utils import load_config

test_network_uuid = load_config("TEST", "test_network_uuid", config_path="~/cxdb/test_config.ini")

# Initialize CXDB and load your knowledge graph
cxdb = CXDB()
ndex_connector = NDExConnector(cxdb, config_path="~/cxdb/test_config.ini")
ndex_connector.from_ndex(test_network_uuid)
cxdb.ndex_connector = ndex_connector

# Helper function to run Cypher queries
def run_query(query):
    result = cxdb.execute_cypher(query)
    print(f"Query: {query}")
    print(f"Result: {result}\n")
    return result

# %%
def get_property_vocabulary(df):
    property_counts = {}
    for _, row in df.iterrows():
        properties = row['properties']
        for prop in properties.keys():
            if prop in property_counts:
                property_counts[prop] += 1
            else:
                property_counts[prop] = 1
    
    # Add built-in properties
    for column in df.columns:
        if column != 'properties':
            property_counts[column] = len(df)

    return dict(sorted(property_counts.items(), key=lambda x: x[1], reverse=True))

def get_node_property_vocabulary(cxdb_db):
    cxdb_db.ndex_connector.from_ndex(test_network_uuid)
    node_properties = get_property_vocabulary(cxdb_db.nodes)
    
    # Print node property vocabulary
    print("Node Property Vocabulary:")
    for prop, count in node_properties.items():
        print(f"{prop}: {count}")

get_node_property_vocabulary(cxdb)
cxdb.nodes
# Out:
# Node Property Vocabulary:
# represents: 33
# location: 33
# id: 33
# name: 33
# type: 33
# member: 4
#     id               name           type  \
# 0    1              PAMPs       stimulus
# 1    2               TLRs  proteinfamily
# 2    3       NfKb-p65/p50        complex
# 3    4    Immune_response      phenotype
# 4    5       Inflammation      phenotype
# 5    6              TIRAP        protein
# 6    7             TICAM1        protein
# 7    8              DAMPS       stimulus
# 8    9        Viral_dsRNA       stimulus
# 9   10              IFIH1        protein
# 10  11            EIF2AK2        protein
# 11  12               DDX1        protein
# 12  13              DDX58        protein
# 13  14    Stress_granules      phenotype
# 14  15        IKK-complex        complex
# 15  16              TRAF6        protein
# 16  17            MAP3K14        protein
# 17  18             STING1        protein
# 18  19               TBK1        protein
# 19  20              MYD88        protein
# 20  21              IRAK1        protein
# 21  22              TRAF3        protein
# 22  23               IRF3        protein
# 23  24              IKBKE        protein
# 24  25               MAVS        protein
# 25  26              DDX21        protein
# 26  27               IRF7        protein
# 27  28  Interferon-type-I  proteinfamily
# 28  29              RIPK1        protein
# 29  30              G3BP1        protein
# 30  31              G3BP2        protein
# 31  32              DHX30        protein
# 32  33              DDX28        protein
#
#                                            properties
# 0   {'represents': 'signor:SIGNOR-ST11', 'location...
# 1   {'represents': 'signor:SIGNOR-PF20', 'location...
# 2   {'represents': 'signor:SIGNOR-C13', 'location'...
# 3   {'represents': 'signor:SIGNOR-PH17', 'location...
# 4   {'represents': 'signor:SIGNOR-PH12', 'location...
# 5   {'represents': 'uniprot:P58753', 'location': '...
# 6   {'represents': 'uniprot:Q8IUC6', 'location': '...
# 7   {'represents': 'signor:SIGNOR-ST18', 'location...
# 8   {'represents': 'signor:SIGNOR-ST21', 'location...
# 9   {'represents': 'uniprot:Q9BYX4', 'location': '...
# 10  {'represents': 'uniprot:P19525', 'location': '...
# 11  {'represents': 'uniprot:Q92499', 'location': '...
# 12  {'represents': 'uniprot:O95786', 'location': '...
# 13  {'represents': 'signor:SIGNOR-PH124', 'locatio...
# 14  {'represents': 'signor:SIGNOR-C14', 'location'...
# 15  {'represents': 'uniprot:Q9Y4K3', 'location': '...
# 16  {'represents': 'uniprot:Q99558', 'location': '...
# 17  {'represents': 'uniprot:Q86WV6', 'location': '...
# 18  {'represents': 'uniprot:Q9UHD2', 'location': '...
# 19  {'represents': 'uniprot:Q99836', 'location': '...
# 20  {'represents': 'uniprot:P51617', 'location': '...
# 21  {'represents': 'uniprot:Q13114', 'location': '...
# 22  {'represents': 'uniprot:Q14653', 'location': '...
# 23  {'represents': 'uniprot:Q14164', 'location': '...
# 24  {'represents': 'uniprot:Q7Z434', 'location': '...
# 25  {'represents': 'uniprot:Q9NR30', 'location': '...
# 26  {'represents': 'uniprot:Q92985', 'location': '...
# 27  {'represents': 'signor:SIGNOR-PF50', 'location...
# 28  {'represents': 'uniprot:Q13546', 'location': '...
# 29  {'represents': 'uniprot:Q13283', 'location': '...
# 30  {'represents': 'uniprot:Q9UN86', 'location': '...
# 31  {'represents': 'uniprot:Q7L2E3', 'location': '...
# 32  {'represents': 'uniprot:Q9NUL7', 'location': '...

# %%
# 1. Get all node types and their counts
query = "MATCH (n:protein) RETURN n.Represents as type, n.location AS location"
run_query(query)
# Out:
# Query: MATCH (n:protein) RETURN n.Represents as type, n.location AS location
# Result: [{'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'factor'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'factor'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}, {'type': None, 'location': 'cytoplasm'}]
# [{'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'factor'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'factor'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'},
#  {'type': None, 'location': 'cytoplasm'}]

# %%
# 2. Find nodes with a specific property value
PROPERTY_NAME = "location"
PROPERTY_VALUE = "cytoplasm"
query = f"MATCH (n:protein) WHERE n.{PROPERTY_NAME} = '{PROPERTY_VALUE}' RETURN n.location AS name, n.type AS type"
run_query(query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 5
#       3 PROPERTY_VALUE = "cytoplasm"
#       4 query = f"MATCH (n:protein) WHERE n.{PROPERTY_NAME} = '{PROPERTY_VALUE}' RETURN n.location AS name, n.type AS type"
# ----> 5 run_query(query)
#
# Cell In[20], line 15, in run_query(query)
#      14 def run_query(query):
# ---> 15     result = cxdb.execute_cypher(query)
#      16     print(f"Query: {query}")
#      17     print(f"Result: {result}\n")
#
# File ~/Dropbox/GitHub/cxdb/cxdb/core.py:19, in CXDB.execute_cypher(self, query)
#      15 def execute_cypher(self, query: str):
#      16     """
#      17     Execute a Cypher query and return the results.
#      18     """
# ---> 19     return self.query_executor.execute(query)
#
# File ~/Dropbox/GitHub/cxdb/cxdb/query_executor.py:12, in CypherQueryExecutor.execute(self, query)
#      10 def execute(self, query: str):
#      11     ast = self.parser.parse(query)
# ---> 12     return self._execute_query(ast)
#
# File ~/Dropbox/GitHub/cxdb/cxdb/query_executor.py:16, in CypherQueryExecutor._execute_query(self, query)
#      14 def _execute_query(self, query):
#      15     if isinstance(query, MatchClause):
# ---> 16         return self._execute_match(query.pattern, query.where, query.return_)
#      17     elif isinstance(query, CreateClause):
#      18         return self._execute_create(query.node_pattern)
#
# File ~/Dropbox/GitHub/cxdb/cxdb/query_executor.py:45, in CypherQueryExecutor._execute_match(self, match, where, return_)
#      43 matched_nodes = self._find_matching_nodes(match)
#      44 if where:
# ---> 45     matched_nodes = self._apply_where_clause(matched_nodes, where)
#      46 return self._process_return_clause(matched_nodes, return_)
#
# File ~/Dropbox/GitHub/cxdb/cxdb/query_executor.py:53, in CypherQueryExecutor._apply_where_clause(self, nodes, where)
#      52 def _apply_where_clause(self, nodes, where):
# ---> 53     property_name = where.condition.property_access.property
#      54     property_value = where.condition.value.strip("'\"")
#      55     return nodes[nodes['properties'].apply(lambda x: self._evaluate_condition(x, (property_name, property_value)))]
#
# AttributeError: 'str' object has no attribute 'condition'

# %%
# 3. Find connections between two specific nodes
NODE1_NAME = "node1_name"
NODE2_NAME = "node2_name"
query = f"MATCH (a {{name: '{NODE1_NAME}'}})-[r]-(b {{name: '{NODE2_NAME}'}}) RETURN a.name AS node1, type(r) AS relationship, b.name AS node2"
run_query(query)

# %%
# 4. Find nodes with the highest degree (most connections)
query = "MATCH (n)-[r]-() RETURN n.name AS node_name, n.type AS node_type, COUNT(r) AS degree ORDER BY degree DESC LIMIT 5"
run_query(query)

# %%
# 5. Find the shortest path between two nodes
START_NODE = "start_node_name"
END_NODE = "end_node_name"
query = f"MATCH p=shortestPath((a {{name: '{START_NODE}'}})-[*]-(b {{name: '{END_NODE}'}})) RETURN [node in nodes(p) | node.name] AS path"
run_query(query)

# %%
# 6. Find subgraphs with a specific pattern
NODE_TYPE1 = "type1"
NODE_TYPE2 = "type2"
RELATIONSHIP_TYPE = "relationship_type"
query = f"MATCH (a:{NODE_TYPE1})-[r:{RELATIONSHIP_TYPE}]->(b:{NODE_TYPE2}) RETURN a.name AS {NODE_TYPE1}, b.name AS {NODE_TYPE2}, r.property AS relationship_property LIMIT 10"
run_query(query)
